# %% [markdown]
# <a href="https://colab.research.google.com/github/darshini458/Machine-Learningprojects/blob/main/Predicting%20type%20of%20cancer%20using%20logistic%20regerssion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
df = pd.read_csv('/content/archive.zip')

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
sample=df.sample(n=5,random_state=10)
sample[['radius_mean', 'texture_mean', 'perimeter_mean','area_mean', 'smoothness_mean','diagnosis']]
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 172       15.460         11.89          102.50      736.9          0.12570
# 553        9.333         21.94           59.01      264.0          0.09240
# 374       13.690         16.07           87.84      579.1          0.08302
# 370       16.350         23.29          109.00      840.4          0.09742
# 419       11.160         21.41           70.95      380.3          0.10180
#
#     diagnosis
# 172         M
# 553         B
# 374         B
# 370         M
# 419         B

# %%
sample[['compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean','diagnosis']]
# Out:
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 172           0.15550        0.203200              0.10970         0.1966
# 553           0.05605        0.039960              0.01282         0.1692
# 374           0.06374        0.025560              0.02031         0.1872
# 370           0.14970        0.181100              0.08773         0.2175
# 419           0.05978        0.008955              0.01076         0.1615
#
#      fractal_dimension_mean diagnosis
# 172                 0.07069         M
# 553                 0.06576         B
# 374                 0.05669         B
# 370                 0.06218         M
# 419                 0.06144         B

# %%
df = df[['diagnosis','radius_mean', 'texture_mean', 'perimeter_mean',
        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']]

# %%
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
X=df.drop('diagnosis',axis=1)
y=df['diagnosis']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=1)

# %%
lor=LogisticRegression(solver='liblinear')
lor.fit(X_train,y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
y_predicted=lor.predict(X_test)
results=pd.DataFrame({'Actual':y_test,'Predicted':y_predicted})
results
# Out:
#     Actual Predicted
# 421      B         B
# 47       M         B
# 292      B         B
# 186      M         M
# 414      M         M
# ..     ...       ...
# 6        M         M
# 487      M         M
# 11       M         M
# 268      B         B
# 419      B         B
#
# [171 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predicted)
# Out:
# 0.8888888888888888

# %%
y_predicted=lor.predict(X_train)
accuracy_score(y_train,y_predicted)
# Out:
# 0.9120603015075377

# %%
y_testprobabilities=lor.predict_proba(X_test)
y_testprobabilities[0:5,:]
# Out:
# array([[0.6233145 , 0.3766855 ],
#        [0.83278577, 0.16721423],
#        [0.95077545, 0.04922455],
#        [0.01205439, 0.98794561],
#        [0.1463116 , 0.8536884 ]])

# %%
y_predicted=lor.predict(X_test)

# %%
probabilities = y_testprobabilities[:, 1]
results = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_predicted,
    'Probability of M': probabilities
})
print(results.head(5))
# Out:
#     Actual Predicted  Probability of M
# 421      B         B          0.376685
# 47       M         B          0.167214
# 292      B         B          0.049225
# 186      M         M          0.987946
# 414      M         M          0.853688
