# %% [markdown]
# <a href="https://colab.research.google.com/github/darshini458/Machine-Learningprojects/blob/main/SVM_using_Scikit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
iris=load_iris()
x=iris.data
y=iris.target
df=pd.DataFrame(x,columns=iris.feature_names)
df['species']=y
df['species'] = df['species'].replace([0, 1, 1], ['septsa', 'virginia', 'vercicolor'])
sns.pairplot(data=df,hue='species',palette='Set2')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
from sklearn.svm import SVC
svm=SVC(kernel='linear',random_state=0)
svm.fit(x_train,y_train)
pred=svm.predict(x_test)
pred
# Out:
# array([2, 1, 2, 0, 1, 1, 2, 0, 0, 2, 2, 1, 0, 1, 2, 2, 0, 0, 0, 2, 2, 1,
#        2, 1, 2, 2, 2, 2, 0, 0])

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
accuracy_score(y_test,pred)
confusion_matrix(y_test,pred)
# Out:
# array([[ 9,  0,  0],
#        [ 0,  7,  0],
#        [ 0,  0, 14]])

# %%
svm2=SVC(kernel='rbf',random_state=0)
svm2.fit(x_train,y_train)
pred2=svm2.predict(x_test)
accuracy_score(y_test,pred2)
# Out:
# 0.9333333333333333
